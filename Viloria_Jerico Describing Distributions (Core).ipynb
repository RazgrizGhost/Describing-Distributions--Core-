# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("medical_dataset.csv")
display(df.head())
df.info()
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 0    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 1    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 2    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# 3    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# 4    VA  37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 0    Male        0  ...             0.0       1.0      1.0                1.0
# 1  Female        0  ...             0.0       0.0      0.0                0.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
# 3    Male        0  ...             0.0       0.0      0.0                0.0
# 4  Female        0  ...             1.0       0.0      0.0                1.0
#
# ...

# %% [markdown]
# # VitD_levels

# %%
vit_mean = df["VitD_levels"].mean()
vit_median = df["VitD_levels"].median()
vit_plus = vit_mean + df["VitD_levels"].std()
vit_minus = vit_mean - df["VitD_levels"].std()

fig,ax = plt.subplots(figsize=(12,6))
sns.histplot(df['VitD_levels'], ax = ax, stat = 'density', kde = True)
ax.axvline(vit_mean, color = 'r', label = f"Mean = {vit_mean}")
ax.axvline(vit_median, color = 'g', ls = "--", label = f"Median = {vit_median}")
ax.axvline(vit_plus, color = "k", label = f"+1 std = {vit_plus}")
ax.axvline(vit_minus, color = "k", label = f"-1 std = {vit_minus}")
ax.axvspan(vit_plus, vit_minus, color = "y", zorder = 0)
ax.legend();

# %%
fig, axes = plt.subplots(1, 2, figsize = (12,6))
sns.histplot(df["VitD_levels"], ax = axes[0])
sns.scatterplot(df["VitD_levels"], ax = axes[1])
# Out:
# <AxesSubplot: ylabel='VitD_levels'>

# %% [markdown]
# ## Answer the following questions
#
# - Is it Discrete or Continuous?
#     - VitD_levels is continuous.
# - Does it have a skew? If so, which direction (+/-)
#     - It skews in the negative direction.
# - What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#     - It displays a Mesokurtic kurtosis.

# %% [markdown]
# # Doc_visits

# %%
doc_mean = df["Doc_visits"].mean()
doc_median = df["Doc_visits"].median()
doc_plus = doc_mean + df["Doc_visits"].std()
doc_minus = doc_mean - df["Doc_visits"].std()

fig,ax = plt.subplots(figsize=(12,6))
sns.histplot(df['Doc_visits'], ax = ax, stat = 'density', kde = True)
ax.axvline(doc_mean, color = 'r', label = f"Mean = {doc_mean}")
ax.axvline(doc_median, color = 'g', ls = "--", label = f"Median = {doc_median}")
ax.axvline(doc_plus, color = "k", label = f"+1 std = {doc_plus}")
ax.axvline(doc_minus, color = "k", label = f"-1 std = {doc_minus}")
ax.axvspan(doc_plus, doc_minus, color = "y", zorder = 0)
ax.legend();

# %%
fig, axes = plt.subplots(1, 2, figsize = (12,6))
sns.histplot(df["Doc_visits"], ax = axes[0])
sns.scatterplot(df["Doc_visits"], ax = axes[1])
# Out:
# <AxesSubplot: ylabel='Doc_visits'>

# %% [markdown]
# ## Answer the following questions
#
# - Is it Discrete or Continuous?
#     - Doc_visits is discrete.
# - Does it have a skew? If so, which direction (+/-)
#     - It does not skew.
# - What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#     - It displays a Leptokurtic kurtosis.

# %% [markdown]
# # TotalCharge

# %%
charge_mean = df["TotalCharge"].mean()
charge_median = df["TotalCharge"].median()
charge_plus = charge_mean + df["TotalCharge"].std()
charge_minus = charge_mean - df["TotalCharge"].std()

fig,ax = plt.subplots(figsize=(12,6))
sns.histplot(df['TotalCharge'], ax = ax, stat = 'density', kde = True)
ax.axvline(charge_mean, color = 'r', label = f"Mean = {charge_mean}")
ax.axvline(charge_median, color = 'g', ls = "--", label = f"Median = {charge_median}")
ax.axvline(charge_plus, color = "k", label = f"+1 std = {charge_plus}")
ax.axvline(charge_minus, color = "k", label = f"-1 std = {charge_minus}")
ax.axvspan(charge_plus, charge_minus, color = "y", zorder = 0)
ax.legend();

# %%
fig, axes = plt.subplots(1, 2, figsize = (12,6))
sns.histplot(df["TotalCharge"], ax = axes[0])
sns.scatterplot(df["TotalCharge"], ax = axes[1])
# Out:
# <AxesSubplot: ylabel='TotalCharge'>

# %% [markdown]
# ## Answer the following questions
#
# - Is it Discrete or Continuous?
#     - TotalCharge is continuous.
# - Does it have a skew? If so, which direction (+/-)
#     - It skews in the positive direction
# - What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#     - It displays a Mesokurtic kurtosis.
